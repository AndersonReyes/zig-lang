# %%
import thinkdsp
import numpy as np
import wave

cos_sig = thinkdsp.CosSignal(freq=440, amp=1.0, offset=0)

# %%
wave = cos_sig.make_wave(duration=0.5, start=0, framerate=1000)

# %%
wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave.write()
# Out:
# Writing sound.wav

# %%
prod_wave = thinkdsp.read_wave("./sound.wav")
test_wave = thinkdsp.read_wave("../main.wav")
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 prod_wave = thinkdsp.read_wave("./sound.wav")
# ----> 2 test_wave = thinkdsp.read_wave("../main.wav")
#
# File ~/Documents/coding/zig-lang/wave/python/thinkdsp.py:98, in read_wave(filename)
#      91 def read_wave(filename="sound.wav"):
#      92     """Reads a wave file.
#      93
#      94     filename: string
#      95
#      96     returns: Wave
#      97     """
# ---> 98     fp = open_wave(filename, "r")
#     100     nchannels = fp.getnchannels()
#     101     nframes = fp.getnframes()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/wave.py:509, in open(f, mode)
#     507         mode = 'rb'
#     508 if mode in ('r', 'rb'):
# --> 509     return Wave_read(f)
#     510 elif mode in ('w', 'wb'):
#     511     return Wave_write(f)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/wave.py:163, in Wave_read.__init__(self, f)
#     161 # else, assume it is an open file object already
#     162 try:
# --> 163     self.initfp(f)
#     164 except:
#     165     if self._i_opened_the_file:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/wave.py:128, in Wave_read.initfp(self, file)
#     126 self._convert = None
#     127 self._soundpos = 0
# --> 128 self._file = Chunk(file, bigendian = 0)
#     129 if self._file.getname() != b'RIFF':
#     130     raise Error('file does not start with RIFF id')
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/chunk.py:63, in Chunk.__init__(self, file, align, bigendian, inclheader)
#      61 self.chunkname = file.read(4)
#      62 if len(self.chunkname) < 4:
# ---> 63     raise EOFError
#      64 try:
#      65     self.chunksize = struct.unpack_from(strflag+'L', file.read(4))[0]
#
# EOFError:

# %%
test_wave.ys[:10]

# %%
prod_wave.ys[:10]

# %%
prod_wave.duration, test_wave.duration

# %%
test_wave.duration

# %%
test_wave.plot()

# %%
prod_wave.plot()

# %%
test_wave.make_audio()

# %%
wv = thinkdsp.open_wave("sound.wav")

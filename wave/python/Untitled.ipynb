# %%
import thinkdsp
import numpy as np
import wave

cos_sig = thinkdsp.CosSignal(freq=440, amp=1.0, offset=0)

# %%
wave = cos_sig.make_wave(duration=0.5, start=0, framerate=1000)

# %%
wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave.write()
# Out:
# Writing sound.wav

# %%
prod_wave = thinkdsp.read_wave("./sound.wav")
test_wave = thinkdsp.read_wave("../main.wav")

# %%
test_wave.ys[:10]
# Out:
# array([ 1.        , -0.92974639,  0.72896512, -0.42576373,  0.06277657,
#         0.30899991, -0.63740959,  0.87627796, -0.99209571,  0.96856594])

# %%
prod_wave.ys[:10]
# Out:
# array([ 1.        , -0.92974639,  0.72896512, -0.42576373,  0.06277657,
#         0.30899991, -0.63740959,  0.87627796, -0.99209571,  0.96856594])

# %%
prod_wave.duration, test_wave.duration
# Out:
# (0.5, 0.5)

# %%
test_wave.duration
# Out:
# 0.5

# %%
test_wave.plot()

# %%
prod_wave.plot()

# %%
test_wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wv = thinkdsp.open_wave("sound.wav")
